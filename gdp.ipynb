# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly as ply
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\Data_Science\금천캠퍼스\데분시각화\김민진\cause_of_death.csv')

# %%
df.columns = df.columns.str.split(' - ').str[1]

# %%
df.columns = ['Entity','Year']+list(df.columns[2:-1])+['total_deaths']

# %%
df.head().T
# Out:
#                                                       0            1  \
# Entity                                      Afghanistan  Afghanistan
# Year                                               1990         1991
# Meningitis                                       2159.0       2218.0
# Alzheimer's disease and other dementias          1116.0       1136.0
# Parkinson's disease                               371.0        374.0
# Nutritional deficiencies                         2087.0       2153.0
# Malaria                                            93.0        189.0
# Drowning                                         1370.0       1391.0
# Interpersonal violence                           1538.0       2001.0
# Maternal disorders                               2655.0       2885.0
# HIV/AIDS                                           34.0         41.0
# Drug use disorders                                 93.0        102.0
# Tuberculosis                                     4661.0       4743.0
# ...

# %%
def country(x):
    if x in list(df['Entity'].unique())[0]:
        return True
    return False

# %%
cond = df['Entity'].apply(country)

# %%
c_df = df[cond]

# %%
c_df
# Out:
#          Entity  Year  Meningitis  Alzheimer's disease and other dementias  \
# 0   Afghanistan  1990      2159.0                                   1116.0
# 1   Afghanistan  1991      2218.0                                   1136.0
# 2   Afghanistan  1992      2475.0                                   1162.0
# 3   Afghanistan  1993      2812.0                                   1187.0
# 4   Afghanistan  1994      3027.0                                   1211.0
# 5   Afghanistan  1995      3102.0                                   1225.0
# 6   Afghanistan  1996      3193.0                                   1239.0
# 7   Afghanistan  1997      3304.0                                   1253.0
# 8   Afghanistan  1998      3281.0                                   1267.0
# 9   Afghanistan  1999      3200.0                                   1281.0
# 10  Afghanistan  2000      3105.0                                   1291.0
# ...

# %%
Afghanistan.head(3).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13776\721350467.py in <module>
# ----> 1 Afghanistan.head(3).T
#
# NameError: name 'Afghanistan' is not defined

# %%
sns.lmplot(
    data=c_df, x="Year", y="Meningitis", col="Entity", hue="Entity",
    height=10    #  ci=None, 
)

# %%
sns.load_dataset("anscombe")
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...
